# %% [markdown]
# ### What is Pandas
# Pandas is a fast, powerful, flexible and easy to use open source data anaylsis and manipulation tool, built on top of the python programming language.
#
# ### Panda Series
# A Pandas Series is like a column in a table. It is a 1-D array holding data of any type.

# %%
# Importing Pandas.
import numpy as np
import pandas as pd

# %%
# series from lists
country =  ['india','Pakithan','USA','Nepal','Srilanka']
pd.Series(country)
# Out:
# 0       india
# 1    Pakithan
# 2         USA
# 3       Nepal
# 4    Srilanka
# dtype: object

# %%
runs = [13,24,56,78,100]
runs_series = pd.Series(runs)

# %%
# custom index
marks = [67,57,89,100]
subjects = ['maths','english','science','hindi']

pd.Series(marks,index=subjects)
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
# setting a name
marks  = pd.Series(marks,index=subjects,name='Ayush ke marks')
marks
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: Ayush ke marks, dtype: int64

# %%
marks = {
    'maths'   : 67,
    'english' : 57,
    'science' : 89,
    'hindi'   : 100
}
marks_series = pd.Series(marks,name="ayush")
print(type(marks_series))
marks_series
# Out:
# <class 'pandas.core.series.Series'>
# maths       67
# english     57
# science     89
# hindi      100
# Name: ayush, dtype: int64

# %% [markdown]
# ### series attribute

# %%
# size
marks_series.size
# Out:
# 4

# %%
# dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
# name
marks_series.name
# Out:
# 'ayush'

# %%
# is_unique 
print(marks_series.is_unique)
pd.Series([1,1,2,3,4,5]).is_unique
# Out:
# True
# False

# %%
# index
marks_series.index
# Out:
# Index(['maths', 'english', 'science', 'hindi'], dtype='object')

# %%
runs_series.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# values
print(marks_series.values)
type(marks_series.values)
# Out:
# [ 67  57  89 100]
# numpy.ndarray

# %% [markdown]
# ##  Series using read_csv

# %%
# with one col
# type(pd.read_csv('C:\projects\pyprojects\data_science\z_Dataset\subs.csv'))

subs = pd.read_csv('C:\projects\pyprojects\data_science\z_Dataset\subs.csv')

# %%
vk = pd.read_csv('C:\projects\pyprojects\data_science\z_Dataset\kohli_ipl.csv',index_col='match_no')
vk
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
bolly_movies = pd.read_csv(r'C:\projects\pyprojects\data_science\z_Dataset\bollywood.csv',index_col='movie')
bolly_movies
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %% [markdown]
# ### Series methods

# %%
# head and tail
subs.head()
# head is used to se starting of the data.
# tail is used to se ending of the data.
# by default the value over here is 5.
# Out:
#    Subscribers gained
# 0                  48
# 1                  57
# 2                  40
# 3                  43
# 4                  44

# %%
vk.head(3)
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13

# %%
vk.tail()
# Out:
#           runs
# match_no
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7

# %%
bolly_movies.tail(3)
# Out:
#                               lead
# movie
# Saathiya (film)       Vivek Oberoi
# Company (film)          Ajay Devgn
# Awara Paagal Deewana  Akshay Kumar

# %%
# sample --> randomly selects data and gives you.
bolly_movies.sample(5)
# Out:
#                                 lead
# movie
# Hisss               Mallika Sherawat
# Haider (film)                   Tabu
# Sunday (2008 film)        Ajay Devgn
# Ekk Deewana Tha              Prateik
# Ishq Ke Parindey         Rishi Verma

# %%
# value_counts --> movies
bolly_movies.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Kashmira Shah        1
# Kartik Elangovan     1
# Karisma Kapoor       1
# Karan Sharma         1
# Zulfi Sayed          1
# Name: count, Length: 566, dtype: int64

# %%
# sort_values --> inplace
vk.sort_values(by='runs',ascending=False)
# Out:
#           runs
# match_no
# 128        113
# 126        109
# 123        108
# 164        100
# 120        100
# ...        ...
# 93           0
# 211          0
# 130          0
# 8            0
# 135          0
#
# [215 rows x 1 columns]

# %%
vk.sort_values(by='runs',ascending=False)
# Out:
#           runs
# match_no
# 128        113
# 126        109
# 123        108
# 164        100
# 120        100
# ...        ...
# 93           0
# 211          0
# 130          0
# 8            0
# 135          0
#
# [215 rows x 1 columns]

# %%
vk.sort_values(by='runs',inplace=True)

# %%
vk
# Out:
#           runs
# match_no
# 87           0
# 211          0
# 207          0
# 206          0
# 91           0
# ...        ...
# 164        100
# 120        100
# 123        108
# 126        109
# 128        113
#
# [215 rows x 1 columns]

# %%
# sort_index --> inplace --> Movies.
bolly_movies.sort_index(ascending=False,inplace=True)
# inplace changes the data permenantly.

# %%
bolly_movies
# Out:
#                                         lead
# movie
# Zor Lagaa Ke...Haiya!          Meghan Jadhav
# Zokkomon                     Darsheel Safary
# Zindagi Tere Naam         Mithun Chakraborty
# Zindagi Na Milegi Dobara      Hrithik Roshan
# Zindagi 50-50                    Veena Malik
# ...                                      ...
# 2 States (2014 film)            Arjun Kapoor
# 1971 (2007 film)              Manoj Bajpayee
# 1920: The Evil Returns           Vicky Ahuja
# 1920: London                   Sharman Joshi
# 1920 (film)                 Rajniesh Duggall
#
# [1500 rows x 1 columns]

# %% [markdown]
# ### Series Maths Methods.

# %%
# count
vk.count()
# Out:
# runs    215
# dtype: int64

# %%
# sum --> product
print(subs.sum())
subs.product()
# Out:
# Subscribers gained    49510
# dtype: int64
# Subscribers gained    0
# dtype: int64

# %%
# mean , median , mode , std , var
subs.mean()
print(vk.median())
print(bolly_movies.mode())
print(subs.std())
print(vk.var())
# Out:
# runs    24.0
# dtype: float64
#            lead
# 0  Akshay Kumar
# Subscribers gained    62.675023
# dtype: float64
# runs    688.002478
# dtype: float64

# %%
# min / max
print(subs.min())
print(subs.max())
# Out:
# Subscribers gained    33
# dtype: int64
# Subscribers gained    396
# dtype: int64

# %%
# describe
vk.describe()
# Out:
#              runs
# count  215.000000
# mean    30.855814
# std     26.229801
# min      0.000000
# 25%      9.000000
# 50%     24.000000
# 75%     48.000000
# max    113.000000

# %%
subs.describe()
# Out:
#        Subscribers gained
# count          365.000000
# mean           135.643836
# std             62.675023
# min             33.000000
# 25%             88.000000
# 50%            123.000000
# 75%            177.000000
# max            396.000000

# %%
bolly_movies.describe()
# Out:
#                 lead
# count           1500
# unique           566
# top     Akshay Kumar
# freq              48

# %% [markdown]
# ### Series Indexing

# %%
# integer indexing
x = pd.Series([12,13,14,35,46,57,58,79,9])
x[1]
# Out:
# 13

# %%
# negative indexing
# x[-1] # there is no negative indexing in series

# %%
bolly_movies
# Out:
#                                         lead
# movie
# Zor Lagaa Ke...Haiya!          Meghan Jadhav
# Zokkomon                     Darsheel Safary
# Zindagi Tere Naam         Mithun Chakraborty
# Zindagi Na Milegi Dobara      Hrithik Roshan
# Zindagi 50-50                    Veena Malik
# ...                                      ...
# 2 States (2014 film)            Arjun Kapoor
# 1971 (2007 film)              Manoj Bajpayee
# 1920: The Evil Returns           Vicky Ahuja
# 1920: London                   Sharman Joshi
# 1920 (film)                 Rajniesh Duggall
#
# [1500 rows x 1 columns]

# %%
# slicing
vk[5:16]
# Out:
#           runs
# match_no
# 93           0
# 8            0
# 130          0
# 135          0
# 106          1
# 113          1
# 77           1
# 75           1
# 1            1
# 174          1
# 5            1

# %%
# negative slicing 
vk[-5:]
# Out:
#           runs
# match_no
# 164        100
# 120        100
# 123        108
# 126        109
# 128        113

# %%
bolly_movies[-5:]
# Out:
#                                     lead
# movie
# 2 States (2014 film)        Arjun Kapoor
# 1971 (2007 film)          Manoj Bajpayee
# 1920: The Evil Returns       Vicky Ahuja
# 1920: London               Sharman Joshi
# 1920 (film)             Rajniesh Duggall

# %%
# fancy indexing
print(vk.index[[1,3,4,5]]) # not working right now
vk
# Out:
# Index([211, 206, 91, 93], dtype='int64', name='match_no')
#           runs
# match_no
# 87           0
# 211          0
# 207          0
# 206          0
# 91           0
# ...        ...
# 164        100
# 120        100
# 123        108
# 126        109
# 128        113
#
# [215 rows x 1 columns]

# %% [markdown]
# ### Editing Series

# %%
# using indexing 
marks_series[1] =100

# %%
marks_series
# Out:
# maths       67
# english    100
# science     89
# hindi      100
# Name: ayush, dtype: int64

# %%
# what if an index does not exist
marks_series['sst'] = 90
marks_series['Data Science'] = 100
marks_series
# Out:
# maths            67
# english         100
# science          89
# hindi           100
# sst              90
# Data Science    100
# Name: ayush, dtype: int64

# %%
# slicing 
runs_series[2:4] = [100,100]
runs_series
# Out:
# 0     13
# 1     24
# 2    100
# 3    100
# 4    100
# dtype: int64

# %%
# fancy indexing 
runs_series[[0,3,4]] = [0,0,0]
runs_series
# Out:
# 0      0
# 1     24
# 2    100
# 3      0
# 4      0
# dtype: int64

# %%
# using index label 
# bolly_movies['Zor Lagaa Ke...Haiya!'] = 'alia bhat'.index()
# bolly_movies

# %% [markdown]
# ### Series with Python Functionaliies

# %%
# len/type/dir/sorted/min/max
print(len(subs))
print(type(subs))
print(dir(subs))
print(sorted(subs.index))
# Out:
# 365
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
# type conversion
list(marks_series)
# Out:
# [67, 100, 89, 100, 90, 100]

# %%
dict(marks_series)
# Out:
# {'maths': 67,
#  'english': 100,
#  'science': 89,
#  'hindi': 100,
#  'sst': 90,
#  'Data Science': 100}

# %%
# membership opertor
'Zokkomon' in bolly_movies.index
# Out:
# True

# %%
# looping 
for i in bolly_movies.index:
    print(i)
# Out:
# Zor Lagaa Ke...Haiya!
# Zokkomon
# Zindagi Tere Naam
# Zindagi Na Milegi Dobara
# Zindagi 50-50
# Zindaggi Rocks
# Zinda (film)
# Zila Ghaziabad
# Zid (2014 film)
# Zero (2018 film)
# Zeher
# Zed Plus
# Zameer: The Fire Within
# Zameen (2003 film)
# Zamaanat
# Yuvvraaj
# Yuva
# Yun Hota Toh Kya Hota
# Youngistaan
# Yeh Saali Aashiqui
# Yeh Mera India
# Yeh Lamhe Judaai Ke
# Yeh Khula Aasmaan
# Yeh Jawaani Hai Deewani
# Yeh Hai India
# Yeh Hai Bakrapur
# Yeh Dooriyan
# Yeh Dil
# Yatra (2007 film)
# Yamla Pagla Deewana: Phir Se
# Yamla Pagla Deewana
# Yakeen (2005 film)
# Yadvi – The Dignified Princess
# Yaaram (2019 film)
# Ya Rab
# Xcuse Me
# Woodstock Villa
# Woh Lamhe...
# Why Cheat India
# What's Your Raashee?
# What the Fish
# Well Done Abba
# Welcome to Sajjanpur
# Welcome Back (film)
# Welcome 2 Karachi
# Welcome (2007 film)
# Wedding Pullav
# Wedding Anniversary
# Waris Shah: Ishq Daa Waaris
# War Chhod Na Yaar
# Waqt: The Race Against Time
# Wanted (2009 film)
# Wake Up Sid
# ...

# %%
# arithmetic operators ( Brodcasting )
100 - marks_series
# Out:
# maths           33
# english          0
# science         11
# hindi            0
# sst             10
# Data Science     0
# Name: ayush, dtype: int64

# %%
# Relational Operators 
vk>=50
# Out:
#            runs
# match_no
# 87        False
# 211       False
# 207       False
# 206       False
# 91        False
# ...         ...
# 164        True
# 120        True
# 123        True
# 126        True
# 128        True
#
# [215 rows x 1 columns]

# %% [markdown]
# ### Boolean Indexing on Series

# %%
# Find no of 50's and 100's scored by kohli.

# %%
# find number of ducks

# %% [markdown]
# #### Plotting graphs on series

# %%
subs.plot()
# Out:
# <Axes: >

# %%
bolly_movies.value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='lead'>

# %%
count = 0 
num = 6
for i in range(1,num):
    if num%i==0:
        count+=1
    
    if count ==2:
        print(True)
    else:
        print (False)
# Out:
# False
# True
# False
# False
# False

# %%
a = 2
b = 3
a = a+b
b = a-b
a = a-b
print(f"a = {a} and b = {b}")
# Out:
# a = 3 and b = 2
